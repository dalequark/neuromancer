# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
files = os.listdir('.')
files = [f for f in files if '_280_100.npy' in f]

# %%
files
# Out:
# ['knn_280_100.npy',
#  'linearsvm_280_100.npy',
#  'logreg_280_100.npy',
#  'svm3_280_100.npy']

# %%
data = [np.load(f) for f in files]

# %%
data2 = [0.518947368421, 0.574, 0.5395, 0.570416666667, 0.575333333333,
       0.534, 0.486363636364, 0.5172, 0.5348, 0.535, 0.547272727273]

# %%
plt.plot(data[0][:,0], label="k Nearest Neighbors")
plt.plot(data[1][:,0], label="Linear SVM")
plt.plot(data2, label="Logistic Regression")
plt.plot(data[3][:,0], label="SVM, Rbf Degree 3")
plt.xlim(-1,12)
plt.xlabel("Participant Number", size=13)
plt.ylabel("12-Fold Accuracy", size=13)
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.title("Classifier Accuracy at offset 280 ms, binwidth 90 ms", size=15, y=1.03)
plt.savefig("/Users/Dale/Dropbox/thesislatex/variousclassifiers", bbox_inches='tight', padding=0.1)
